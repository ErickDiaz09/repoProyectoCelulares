# %% [markdown]
# #Carga e inspección inicial de los datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Programación 2/Proyecto final"
# Out:
# /content/drive/MyDrive/Programación 2/Proyecto final

# %%
# !ls
# Out:
#  Global_Mobile_Prices_2025_Extended.csv  'Proyecto Final.ipynb'

# %%
import pandas as pd

df = pd.read_csv("Global_Mobile_Prices_2025_Extended.csv")
print(df.head())
# Out:
#     brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0    Oppo                A98 111        855      16         128        108
# 1  Realme            11 Pro+ 843        618       6         128         64
# 2  Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3    Vivo               V29e 744        837       6         512         48
# 4   Apple  iPhone 16 Pro Max 927        335      12         128        200
#
#    battery_mah  display_size_inch  charging_watt 5g_support       os  \
# 0         6000                6.6             33        Yes  Android
# 1         4500                6.9            100        Yes  Android
# 2         4000                6.8             44        Yes  Android
# 3         4500                6.0             65        Yes  Android
# 4         5000                6.9            100        Yes      iOS
#
#         processor  rating release_month  year
# 0       Helio G99     3.8      February  2025
# ...

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              1000 non-null   object
#  1   model              1000 non-null   object
#  2   price_usd          1000 non-null   int64
#  3   ram_gb             1000 non-null   int64
#  4   storage_gb         1000 non-null   int64
#  5   camera_mp          1000 non-null   int64
#  6   battery_mah        1000 non-null   int64
#  7   display_size_inch  1000 non-null   float64
#  8   charging_watt      1000 non-null   int64
#  9   5g_support         1000 non-null   object
#  10  os                 1000 non-null   object
#  11  processor          1000 non-null   object
#  12  rating             1000 non-null   float64
#  13  release_month      1000 non-null   object
#  14  year               1000 non-null   int64
# dtypes: float64(2), int64(7), object(6)
# ...

# %%
df.describe()
# Out:
#          price_usd      ram_gb   storage_gb    camera_mp  battery_mah  \
# count  1000.000000  1000.00000  1000.000000  1000.000000  1000.000000
# mean    813.478000     9.17200   402.880000    83.534000  5012.000000
# std     411.708367     4.32633   349.405893    62.504958   711.591429
# min     101.000000     4.00000    64.000000    12.000000  4000.000000
# 25%     449.250000     6.00000   128.000000    48.000000  4500.000000
# 50%     822.000000     8.00000   256.000000    64.000000  5000.000000
# 75%    1166.250000    12.00000   512.000000   108.000000  5500.000000
# max    1499.000000    16.00000  1024.000000   200.000000  6000.000000
#
#        display_size_inch  charging_watt       rating    year
# count        1000.000000    1000.000000  1000.000000  1000.0
# mean            6.380600      63.791000     4.229900  2025.0
# std             0.496841      36.333751     0.439965     0.0
# min             5.500000      18.000000     3.500000  2025.0
# ...

# %% [markdown]
# #Manejo de datos faltantes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False)
plt.title("Mapa de valores faltantes")
plt.show()

# %% [markdown]
# #Identificación de outliers

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["price_usd"])
plt.title('Precio en Dolares')
plt.ylabel('Precio en USD')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["ram_gb"])
plt.title('Memoria Ram de cada Dispositivo(gb)')
plt.ylabel('Dispositivos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["storage_gb"])
plt.title('Almacenamiento de los dispositivos(gb)')
plt.ylabel('Dispositivos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["camera_mp"])
plt.title('Camara de los dispositivos(mp)')
plt.ylabel('Dispositivos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["battery_mah"])
plt.title('Bateria de los dispositivos(mha)')
plt.ylabel('Dispositivos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["charging_watt"])
plt.title('Capacidad de carga de los dispositivos(watt)')
plt.ylabel('Dispositivos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["display_size_inch"])
plt.title('Tamaño de la pntalla de los dispositivos(inc)')
plt.ylabel('Dispositivos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["rating"])
plt.title('Calificación de los dispositivos')
plt.ylabel('Dispositivos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x=df["year"])
plt.title('Año de lanzamiento de los dispositivos')
plt.ylabel('Dispositivos')
plt.show()

# %% [markdown]
# #Tratamiento de valores inconsistentes en texto y duplicados.

# %% [markdown]
# ##Tratamiento de valores inconsistentes en texto

# %%
df['brand'].value_counts()
# Out:
# brand
# Vivo       122
# Google     116
# OnePlus    116
# Xiaomi     114
# Oppo       110
# Apple      107
# Realme     105
# Infinix    105
# Samsung    105
# Name: count, dtype: int64

# %%
df['model'].value_counts()
# Out:
# model
# Narzo 70 451            2
# Narzo 70 335            2
# iPhone 14 583           2
# Nord CE 4 Lite 268      2
# Galaxy S24 Ultra 700    2
#                        ..
# Reno 11 35              1
# Narzo 70 534            1
# Nord 4 900              1
# iPhone 16 293           1
# Nord CE 4 Lite 241      1
# Name: count, Length: 992, dtype: int64

# %%
df['5g_support'].value_counts()
# Out:
# 5g_support
# Yes    503
# No     497
# Name: count, dtype: int64

# %%
df['os'].value_counts()
# Out:
# os
# Android    893
# iOS        107
# Name: count, dtype: int64

# %%
df['processor'].value_counts()
# Out:
# processor
# Dimensity 9300         138
# Tensor G4              133
# Snapdragon 8 Gen 3     132
# Helio G99              128
# Exynos 2400            124
# Snapdragon 6 Gen 1     118
# Snapdragon 7+ Gen 2    115
# A18 Pro                112
# Name: count, dtype: int64

# %%
df["ram_gb"].value_counts()
# Out:
# ram_gb
# 6     210
# 4     202
# 16    200
# 12    200
# 8     188
# Name: count, dtype: int64

# %%
df['release_month'].value_counts()
# Out:
# release_month
# April        101
# January       95
# July          93
# October       86
# August        85
# February      84
# June          82
# December      80
# March         77
# November      73
# September     73
# May           71
# Name: count, dtype: int64

# %% [markdown]
# ##Tratamiento de valores duplicados

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [brand, model, price_usd, ram_gb, storage_gb, camera_mp, battery_mah, display_size_inch, charging_watt, 5g_support, os, processor, rating, release_month, year]
# Index: []

# %% [markdown]
# #Creación de variables

# %% [markdown]
# ##Se crea una variable presupesto con respecto al precio

# %%
dif=df["price_usd"].max()-df["price_usd"].min()
pbajo=dif/3
print(df["price_usd"].min())
print(df["price_usd"].max())
print(f"Diferencia de rango de precio:{pbajo}")
print(f"Precio bajo <= {pbajo}")
print(f"Precio medio <= {pbajo*2}")
print(f"Precio alto > {pbajo*2}")
# Out:
# 101
# 1499
# Diferencia de rango de precio:466.0
# Precio bajo <= 466.0
# Precio medio <= 932.0
# Precio alto > 932.0

# %%
def Budget(price):
    if price <= 466:
        return "Low"
    elif price <= 932:
        return "Mid"
    else:
        return "High"

df["budget"] = df["price_usd"].apply(Budget)

# %%
df
# Out:
#        brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0       Oppo                A98 111        855      16         128        108
# 1     Realme            11 Pro+ 843        618       6         128         64
# 2     Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3       Vivo               V29e 744        837       6         512         48
# 4      Apple  iPhone 16 Pro Max 927        335      12         128        200
# ..       ...                    ...        ...     ...         ...        ...
# 995   Google             Pixel 7a 2        961       8         256         12
# 996  OnePlus        OnePlus 13R 423        158      16          64         64
# 997   Xiaomi        Poco X6 Pro 796       1164       6         128        200
# 998   Realme           Narzo 70 809        895       8          64         48
# 999   Xiaomi        Mi 13 Ultra 429        458      16         512         64
#
# ...

# %% [markdown]
# ##Se crea una variable con respecto al tamaño de la pantalla

# %%
dif=df["display_size_inch"].max()-df["display_size_inch"].min()
min=df["display_size_inch"].min()
tp=round(dif/3,2)
print(min)
print(df["display_size_inch"].max())
print(f"Diferencia de rango de precio:{dif}")
print(f"Tamaño pequeña <= {min+tp}")
print(f"Tamaño mediana <= {min+(tp*2)}")
print(f"Tamaño grande > {min+(tp*2)}")
# Out:
# 5.5
# 7.2
# Diferencia de rango de precio:1.7000000000000002
# Tamaño pequeña <= 6.07
# Tamaño mediana <= 6.64
# Tamaño grande > 6.64

# %%
def Screen_size(display_size_inch):
    if display_size_inch <= 6.07:
        return "Small"
    elif display_size_inch <= 6.64:
        return "Medium"
    else :
        return "Big"
df["screen_size"] = df["display_size_inch"].apply(Screen_size)

# %%
df
# Out:
#        brand                  model  price_usd  ram_gb  storage_gb  camera_mp  \
# 0       Oppo                A98 111        855      16         128        108
# 1     Realme            11 Pro+ 843        618       6         128         64
# 2     Xiaomi  Redmi Note 14 Pro 461        258      16          64         64
# 3       Vivo               V29e 744        837       6         512         48
# 4      Apple  iPhone 16 Pro Max 927        335      12         128        200
# ..       ...                    ...        ...     ...         ...        ...
# 995   Google             Pixel 7a 2        961       8         256         12
# 996  OnePlus        OnePlus 13R 423        158      16          64         64
# 997   Xiaomi        Poco X6 Pro 796       1164       6         128        200
# 998   Realme           Narzo 70 809        895       8          64         48
# 999   Xiaomi        Mi 13 Ultra 429        458      16         512         64
#
# ...

# %% [markdown]
# #Filtrado y condiciones en Pandas

# %%
df

# %%
df[(df["price_usd"]>900)].shape[0]
# Out:
# 437

# %%
df[(df["price_usd"]>900)&(df["rating"]>=4.0)].shape[0]
# Out:
# 291

# %% [markdown]
# Aunque mas de la mitad tenga un valor superior a 900 no todos tiene una calificacion correspondiente a su precio

# %%
df[(df["ram_gb"]>=16)&(df["storage_gb"]>=512)]["brand"].value_counts()
# Out:
# brand
# Oppo       13
# Vivo       12
# Xiaomi     12
# Google     11
# Samsung     9
# OnePlus     7
# Infinix     7
# Realme      6
# Apple       2
# Name: count, dtype: int64

# %% [markdown]
# Despues de realizar un filtrado nos damos cuenta que oppo y google tiene las mejores caracteristicas de almacenamiento

# %%
df[(df["camera_mp"]>=200)]["os"].value_counts()
# Out:
# os
# Android    168
# iOS         20
# Name: count, dtype: int64

# %% [markdown]
# Aunque por  cantidad haya mas celulares andorid por porcentaje tienen la misma cantidad con mas de 200 mp de camara aproximadamente un 18%

# %%
df[(df["battery_mah"]>=6000)&(df["charging_watt"]>=120)]["brand"].value_counts()
# Out:
# brand
# Xiaomi     7
# Apple      6
# Google     4
# Oppo       4
# Samsung    3
# Vivo       3
# Realme     2
# Infinix    1
# Name: count, dtype: int64

# %% [markdown]
# Xiaomi es la mejor marca de celulares con el poder de carga de la bateria

# %%
df[(df["rating"]>=5.0)]["brand"].value_counts()
# Out:
# brand
# Realme     8
# Infinix    7
# Samsung    7
# OnePlus    6
# Oppo       5
# Google     5
# Vivo       3
# Apple      2
# Xiaomi     2
# Name: count, dtype: int64

# %% [markdown]
# Realme seguido de infinix y Samsung han sacado los mejores celulares en este ultimo tiemp segun las personas

# %% [markdown]
# # Agrupación con groupby

# %%
df.groupby("brand")["display_size_inch"].mean()
#
# Out:
# brand
# Apple      6.422430
# Google     6.394828
# Infinix    6.419048
# OnePlus    6.317241
# Oppo       6.388182
# Realme     6.350476
# Samsung    6.305714
# Vivo       6.440164
# Xiaomi     6.381579
# Name: display_size_inch, dtype: float64

# %% [markdown]
# Samsung es la marca que mas ram en promedio de los celulares, aunque todas esten aproximadamente en el mismo valor

# %%
df.groupby("brand")["price_usd"].mean()
# Out:
# brand
# Apple      835.691589
# Google     808.060345
# Infinix    839.171429
# OnePlus    812.250000
# Oppo       826.327273
# Realme     771.780952
# Samsung    791.723810
# Vivo       807.901639
# Xiaomi     827.736842
# Name: price_usd, dtype: float64

# %% [markdown]
# Se evidencia que  no es normal los precios y que no tienen una tendencia, pero que el usd de mas cantidad es aproximadamente de 900

# %%
df.groupby("os")["5g_support"].value_counts()
# Out:
# os       5g_support
# Android  Yes           451
#          No            442
# iOS      No             55
#          Yes            52
# Name: count, dtype: int64

# %% [markdown]
# Aproximadamente el 50% de cada celular del sistema operativo tiene 5G

# %%
df.groupby("brand")[["ram_gb","storage_gb","battery_mah"]].value_counts()
# Out:
# brand   ram_gb  storage_gb  battery_mah
# Apple   6       512         4000           5
#         4       128         5000           4
#         8       512         4000           4
#         16      256         6000           4
#         4       128         4500           3
#                                           ..
# Xiaomi  16      512         4000           1
#                             4500           1
#                             6000           1
#                 1024        5000           1
#                             5500           1
# Name: count, Length: 651, dtype: int64

# %% [markdown]
# Los modelos de la marca Apple suelen tener las mismas caracteristicas mientras que en las demas marcas, las caracteristicas varian en cada modelo.

# %%
df.groupby("rating")["charging_watt"].mean()
# Out:
# rating
# 3.5    66.300000
# 3.6    67.178082
# 3.7    60.701299
# 3.8    64.957746
# 3.9    55.773333
# 4.0    53.323529
# 4.1    65.971429
# 4.2    66.034483
# 4.3    62.409091
# 4.4    68.623377
# 4.5    67.781818
# 4.6    69.385965
# 4.7    61.442308
# 4.8    62.750000
# 4.9    66.000000
# 5.0    66.200000
# Name: charging_watt, dtype: float64

# %% [markdown]
# Estas 2 variables no se relacionan, ya que mientras el raiting aumenta, el charging watt puede ser menor o mayor, es decir que no dependen la uno de la otra.

# %% [markdown]
# # Visualizaciones

# %%
plt.figure(figsize=(8,6))
df.boxplot(column="price_usd", by="os")
plt.xlabel("Sistema operativo")
plt.ylabel("Precio (USD)")
plt.title("Distribución del precio por sistema operativo")
plt.suptitle("")
plt.tight_layout()
plt.show()

# %% [markdown]
# Ambas compañias de sistema operativo no tiene diferencia en sus precios

# %%
ram_mean = df.groupby("brand")["ram_gb"].mean().sort_values()
plt.figure(figsize=(12,5))
plt.bar(ram_mean.index, ram_mean.values)
plt.xticks(rotation=90)
plt.ylabel("RAM promedio (GB)")
plt.title("RAM promedio por marca")
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("Global_Mobile_Prices_2025_Extended.csv")
group_counts = df.groupby(["os", "5g_support"]).size().unstack(fill_value=0)
plt.figure(figsize=(10,6))
group_counts.plot(kind="bar", stacked=True)
plt.xlabel("Sistema Operativo")
plt.ylabel("Cantidad de teléfonos")
plt.title("Distribución de Soporte 5G por Sistema Operativo")
plt.legend(["No 5G", "Sí 5G"], title="5G Support")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Global_Mobile_Prices_2025_Extended.csv")

plt.figure(figsize=(10,5))
plt.hist(df["price_usd"], bins=20, edgecolor="black")
plt.xlabel("Precio USD")
plt.ylabel("Frecuencia")
plt.title("Histograma de precios de teléfonos")
plt.tight_layout()
plt.show()

# %%
df[["ram_gb","storage_gb","battery_mah"]].hist(figsize=(12,6), bins=15,)
plt.suptitle("Histogramas de especificaciones principales")
plt.tight_layout()
plt.show()

# %% [markdown]
# RAM: De las capacidades existentes de RAM, estan muy parejas y no hay una que destque entre las otras
#
# Storage: La mayor cantidad de celulares estan en menos de 200 de almacenamiento
#
# battery: Los valores estan de igual manera dispersados en cada uno de los amperios
